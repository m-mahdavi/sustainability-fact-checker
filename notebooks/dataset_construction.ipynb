# %% [markdown]
# # Dataset Construction

# %% [markdown]
# ## Importing Libraries

# %%
import os
import sys

sys.path.append("../source")
import document

# %% [markdown]
# ## Extracting Images

# %%
url = "../documents/Citi.pdf" # Or a URL like: "https://css4.pub/2017/newsletter/drylab.pdf"
doc = document.Document(url=url)
content = doc.read_local_file() # If URL: doc.request_url()
doc.content_type = "pdf"
extracted_images = doc.extract_images(content)
file_name = os.path.basename(url)
output_folder = os.path.join("../images", file_name)
os.makedirs(output_folder, exist_ok=True)
for i, image in enumerate(extracted_images):
    file_path = os.path.join(output_folder, f"{i}.{image['ext']}")
    with open(file_path, "wb") as f:
        f.write(image["image_bytes"])
    print(f"Saved {file_path}.")
# Out:
# Saved ../images/Citi.pdf/0.jpx.
# Saved ../images/Citi.pdf/1.jpx.
# Saved ../images/Citi.pdf/2.jpx.
# Saved ../images/Citi.pdf/3.jpx.
# Saved ../images/Citi.pdf/4.jpx.
# Saved ../images/Citi.pdf/5.jpx.
# Saved ../images/Citi.pdf/6.jpx.
# Saved ../images/Citi.pdf/7.jpx.
# Saved ../images/Citi.pdf/8.png.
# Saved ../images/Citi.pdf/9.jpx.
# Saved ../images/Citi.pdf/10.jpx.
# Saved ../images/Citi.pdf/11.jpx.
# Saved ../images/Citi.pdf/12.jpx.
# Saved ../images/Citi.pdf/13.jpx.
# Saved ../images/Citi.pdf/14.jpx.
# Saved ../images/Citi.pdf/15.jpx.
# Saved ../images/Citi.pdf/16.jpx.
# Saved ../images/Citi.pdf/17.jpx.
# Saved ../images/Citi.pdf/18.jpx.
# Saved ../images/Citi.pdf/19.jpx.
# Saved ../images/Citi.pdf/20.jpx.
# Saved ../images/Citi.pdf/21.jpx.
# Saved ../images/Citi.pdf/22.jpx.
# Saved ../images/Citi.pdf/23.png.
# Saved ../images/Citi.pdf/24.jpx.
# Saved ../images/Citi.pdf/25.jpx.
# Saved ../images/Citi.pdf/26.jpx.
# Saved ../images/Citi.pdf/27.jpx.
# Saved ../images/Citi.pdf/28.jpx.
# Saved ../images/Citi.pdf/29.jpx.
# Saved ../images/Citi.pdf/30.jpx.
# Saved ../images/Citi.pdf/31.jpx.
# Saved ../images/Citi.pdf/32.jpx.
# Saved ../images/Citi.pdf/33.jpx.
# Saved ../images/Citi.pdf/34.jpx.
# Saved ../images/Citi.pdf/35.jpx.
# Saved ../images/Citi.pdf/36.jpx.
# Saved ../images/Citi.pdf/37.jpx.
# Saved ../images/Citi.pdf/38.jpx.
# Saved ../images/Citi.pdf/39.jpx.
# Saved ../images/Citi.pdf/40.jpx.
# Saved ../images/Citi.pdf/41.jpx.
# Saved ../images/Citi.pdf/42.jpx.
# Saved ../images/Citi.pdf/43.jpx.
# Saved ../images/Citi.pdf/44.jpx.
# Saved ../images/Citi.pdf/45.jpx.
# Saved ../images/Citi.pdf/46.jpx.
# Saved ../images/Citi.pdf/47.jpx.
# Saved ../images/Citi.pdf/48.jpx.
# Saved ../images/Citi.pdf/49.jpx.
# Saved ../images/Citi.pdf/50.jpx.
# Saved ../images/Citi.pdf/51.jpx.
# Saved ../images/Citi.pdf/52.jpx.
# Saved ../images/Citi.pdf/53.jpx.
# Saved ../images/Citi.pdf/54.jpx.
# Saved ../images/Citi.pdf/55.jpx.
# Saved ../images/Citi.pdf/56.jpx.
# Saved ../images/Citi.pdf/57.jpx.
# Saved ../images/Citi.pdf/58.jpx.
# Saved ../images/Citi.pdf/59.jpx.
# Saved ../images/Citi.pdf/60.jpx.
# Saved ../images/Citi.pdf/61.jpx.
# Saved ../images/Citi.pdf/62.jpx.
# Saved ../images/Citi.pdf/63.jpx.
# Saved ../images/Citi.pdf/64.jpx.
# Saved ../images/Citi.pdf/65.jpx.
# Saved ../images/Citi.pdf/66.jpx.
# Saved ../images/Citi.pdf/67.jpx.
# Saved ../images/Citi.pdf/68.jpx.
# Saved ../images/Citi.pdf/69.jpx.
# Saved ../images/Citi.pdf/70.jpx.
# Saved ../images/Citi.pdf/71.jpx.
# Saved ../images/Citi.pdf/72.jpx.
# Saved ../images/Citi.pdf/73.jpx.
# Saved ../images/Citi.pdf/74.jpx.
# Saved ../images/Citi.pdf/75.jpx.
# Saved ../images/Citi.pdf/76.png.
# Saved ../images/Citi.pdf/77.png.
# Saved ../images/Citi.pdf/78.png.
# Saved ../images/Citi.pdf/79.png.
# Saved ../images/Citi.pdf/80.png.
# Saved ../images/Citi.pdf/81.png.
# Saved ../images/Citi.pdf/82.png.
# Saved ../images/Citi.pdf/83.png.
# Saved ../images/Citi.pdf/84.png.
# Saved ../images/Citi.pdf/85.png.
# Saved ../images/Citi.pdf/86.png.
# Saved ../images/Citi.pdf/87.png.
# Saved ../images/Citi.pdf/88.png.
# Saved ../images/Citi.pdf/89.png.
# Saved ../images/Citi.pdf/90.png.
# Saved ../images/Citi.pdf/91.png.
# Saved ../images/Citi.pdf/92.png.
# Saved ../images/Citi.pdf/93.png.
# Saved ../images/Citi.pdf/94.png.
# Saved ../images/Citi.pdf/95.png.
# Saved ../images/Citi.pdf/96.png.
# Saved ../images/Citi.pdf/97.png.
# Saved ../images/Citi.pdf/98.png.
# Saved ../images/Citi.pdf/99.png.
# Saved ../images/Citi.pdf/100.png.
# Saved ../images/Citi.pdf/101.png.
# Saved ../images/Citi.pdf/102.png.
# Saved ../images/Citi.pdf/103.png.
# Saved ../images/Citi.pdf/104.png.
# Saved ../images/Citi.pdf/105.png.
# Saved ../images/Citi.pdf/106.jpx.
# Saved ../images/Citi.pdf/107.png.
# Saved ../images/Citi.pdf/108.png.
# Saved ../images/Citi.pdf/109.png.
# Saved ../images/Citi.pdf/110.png.
# Saved ../images/Citi.pdf/111.png.
# Saved ../images/Citi.pdf/112.png.
# Saved ../images/Citi.pdf/113.png.
# Saved ../images/Citi.pdf/114.png.
# Saved ../images/Citi.pdf/115.jpx.
# Saved ../images/Citi.pdf/116.png.
# Saved ../images/Citi.pdf/117.png.
# Saved ../images/Citi.pdf/118.png.
# Saved ../images/Citi.pdf/119.png.
